# %%
import csv
from google.colab import files

qa_pairs = [
    {"Question": "What is the price of product X?", "Answer": "The price of product X is $199."},
    {"Question": "Do you offer discounts?", "Answer": "Yes, we offer seasonal discounts and special offers for members."},
    {"Question": "Can I return a product if I'm not satisfied?", "Answer": "Yes, we have a 30-day return policy for unsatisfied customers."},
    {"Question": "What are your shipping options?", "Answer": "We offer standard, expedited, and overnight shipping options."},
    {"Question": "How can I track my order?", "Answer": "You can track your order using the tracking link sent to your email after purchase."},
    {"Question": "What payment methods do you accept?", "Answer": "We accept credit/debit cards, PayPal, and Apple Pay."},
    {"Question": "Do you ship internationally?", "Answer": "Yes, we ship to many countries worldwide. Shipping rates may vary."},
    {"Question": "How long does it take to process a refund?", "Answer": "Refunds are processed within 5-7 business days after receiving the returned item."},
    {"Question": "Do you offer gift wrapping services?", "Answer": "Yes, we offer gift wrapping services at an additional cost."},
    {"Question": "What is the warranty on your products?", "Answer": "Our products come with a 1-year warranty covering manufacturing defects."},
    {"Question": "How can I contact customer support?", "Answer": "You can contact our customer support via phone, email, or live chat on our website."},
    {"Question": "Are there any loyalty programs?", "Answer": "Yes, we have a loyalty program that offers points for purchases which can be redeemed for discounts."},
    {"Question": "Can I change my order after placing it?", "Answer": "You can change your order within 24 hours of placing it by contacting customer support."},
    {"Question": "What is the best-selling product in your store?", "Answer": "Our best-selling product is the SmartWatch Pro 3000."},
    {"Question": "Do you offer free samples?", "Answer": "Yes, we offer free samples with certain promotions and purchases."},
    {"Question": "How do I know if a product is in stock?", "Answer": "You can check the stock availability on the product page before purchasing."},
    {"Question": "Do you have any eco-friendly products?", "Answer": "Yes, we offer a range of eco-friendly and sustainable products."},
    {"Question": "Can I get a product catalog?", "Answer": "You can download our product catalog from the 'Resources' section of our website."},
    {"Question": "How can I leave a review for a product?", "Answer": "You can leave a review on the product page by clicking the 'Write a Review' button."},
    {"Question": "What are your store hours?", "Answer": "Our store hours are Monday to Friday, 9 AM to 6 PM."},
    {"Question": "Do you have any physical stores?", "Answer": "Yes, we have physical stores in several major cities. You can find the nearest one on our website."},
    {"Question": "Can I preorder a product?", "Answer": "Yes, we offer preorder options for select products. Check the product page for details."},
    {"Question": "Do you have a referral program?", "Answer": "Yes, you can refer a friend and earn discounts on your next purchase."},
    {"Question": "Are your products tested on animals?", "Answer": "No, all our products are cruelty-free and not tested on animals."},
    {"Question": "What is the shelf life of your products?", "Answer": "The shelf life of our products varies, but most have a lifespan of 1-2 years."},
    {"Question": "Can I schedule a delivery for a specific date?", "Answer": "Yes, you can schedule a delivery during checkout by selecting a preferred date."},
    {"Question": "Do you offer bulk purchase discounts?", "Answer": "Yes, we offer discounts on bulk purchases. Contact sales for more details."},
    {"Question": "How do I apply a discount code?", "Answer": "You can apply a discount code at checkout in the 'Promo Code' field."},
    {"Question": "What happens if my package is lost?", "Answer": "If your package is lost, contact customer support for a replacement or refund."},
    {"Question": "Do you sell gift cards?", "Answer": "Yes, we offer digital gift cards that can be emailed directly to the recipient."},
    {"Question": "Can I customize a product?", "Answer": "We offer customization on select products. Check the product page for customization options."},
    {"Question": "What is the minimum order quantity for bulk orders?", "Answer": "The minimum order quantity for bulk orders varies by product. Please contact sales for details."},
    {"Question": "Can I subscribe to product updates?", "Answer": "Yes, you can subscribe to our newsletter for the latest product updates and offers."},
    {"Question": "Do you have any seasonal sales?", "Answer": "Yes, we have seasonal sales during major holidays like Black Friday and Christmas."},
    {"Question": "How do I create an account?", "Answer": "You can create an account by clicking 'Sign Up' on our website and filling out the required information."},
    {"Question": "Can I cancel my subscription?", "Answer": "Yes, you can cancel your subscription anytime from your account settings."},
    {"Question": "What is the difference between product X and product Y?", "Answer": "Product X has a longer battery life, while product Y offers more color options."},
    {"Question": "Is there a way to compare products?", "Answer": "Yes, our website offers a product comparison feature. You can add products to the comparison list and view their differences side by side."},
    {"Question": "How often do you restock items?", "Answer": "We restock popular items every few weeks, depending on demand."},
    {"Question": "Do you offer technical support for your products?", "Answer": "Yes, we provide technical support for all our products. You can contact our support team via phone or email."},
    {"Question": "Can I request a product demo?", "Answer": "Yes, you can request a product demo by contacting our sales team."},
    {"Question": "Are there any upcoming product launches?", "Answer": "Yes, we have several exciting product launches planned. Subscribe to our newsletter for updates."},
    {"Question": "Do you have any products for kids?", "Answer": "Yes, we offer a range of products specifically designed for kids."},
    {"Question": "Can I order replacement parts?", "Answer": "Yes, you can order replacement parts through our website or by contacting customer support."},
    {"Question": "How do I know if a product is compatible with my device?", "Answer": "Compatibility information is available on the product page under the 'Specifications' section."},
    {"Question": "What is your environmental policy?", "Answer": "Our environmental policy focuses on sustainability and reducing waste. We use eco-friendly packaging and materials."},
    {"Question": "How can I provide feedback on your service?", "Answer": "You can provide feedback through our website's feedback form or by contacting customer support."},
    {"Question": "Do you offer financing options?", "Answer": "Yes, we offer financing options through our partner financial institutions. Details are available at checkout."},
    {"Question": "How do I create an account?", "Answer": "You can create an account by clicking 'Sign Up' on our website and filling out the required information."},
    {"Question": "Can I cancel my subscription?", "Answer": "Yes, you can cancel your subscription anytime from your account settings."},
    {"Question": "What is the difference between product X and product Y?", "Answer": "Product X has a longer battery life, while product Y offers more color options."},
    {"Question": "Is there a way to compare products?", "Answer": "Yes, our website offers a product comparison feature. You can add products to the comparison list and view their differences side by side."},
    {"Question": "How often do you restock items?", "Answer": "We restock popular items every few weeks, depending on demand."},
    {"Question": "Do you offer technical support for your products?", "Answer": "Yes, we provide technical support for all our products. You can contact our support team via phone or email."},
    {"Question": "Can I request a product demo?", "Answer": "Yes, you can request a product demo by contacting our sales team."},
    {"Question": "Are there any upcoming product launches?", "Answer": "Yes, we have several exciting product launches planned. Subscribe to our newsletter for updates."},
    {"Question": "Do you have any products for kids?", "Answer": "Yes, we offer a range of products specifically designed for kids."},
    {"Question": "Can I order replacement parts?", "Answer": "Yes, you can order replacement parts through our website or by contacting customer support."},
    {"Question": "How do I know if a product is compatible with my device?", "Answer": "Compatibility information is available on the product page under the 'Specifications' section."},
    {"Question": "What is your environmental policy?", "Answer": "Our environmental policy focuses on sustainability and reducing waste. We use eco-friendly packaging and materials."},
    {"Question": "How can I provide feedback on your service?", "Answer": "You can provide feedback through our website's feedback form or by contacting customer support."},
    {"Question": "Do you offer financing options?", "Answer": "Yes, we offer financing options through our partner financial institutions. Details are available at checkout."},
    {"Question": "How can I subscribe to product updates?", "Answer": "You can subscribe to our newsletter for the latest product updates and offers."},
    {"Question": "Do you have any seasonal sales?", "Answer": "Yes, we have seasonal sales during major holidays like Black Friday and Christmas."},
    {"Question": "How do I apply a discount code?", "Answer": "You can apply a discount code at checkout in the 'Promo Code' field."},
    {"Question": "What happens if my package is lost?", "Answer": "If your package is lost, contact customer support for a replacement or refund."},
    {"Question": "Do you sell gift cards?", "Answer": "Yes, we offer digital gift cards that can be emailed directly to the recipient."},
    {"Question": "Can I customize a product?", "Answer": "We offer customization on select products. Check the product page for customization options."},
    {"Question": "What is the minimum order quantity for bulk orders?", "Answer": "The minimum order quantity for bulk orders varies by product. Please contact sales for details."},
    {"Question": "Can I track my order in real-time?", "Answer": "Yes, you can track your order in real-time through the tracking link sent via email."},
    {"Question": "Are there any loyalty programs?", "Answer": "Yes, we have a loyalty program that offers points for purchases which can be redeemed for discounts."},
    {"Question": "How do I update my payment information?", "Answer": "You can update your payment information in the 'Account Settings' section of our website."},
    {"Question": "What is the process for bulk orders?", "Answer": "For bulk orders, please contact our sales team for customized quotes and delivery timelines."},
    {"Question": "Do you offer corporate discounts?", "Answer": "Yes, we offer corporate discounts. Contact our sales department for more information."},
    {"Question": "How do I reset my password?", "Answer": "You can reset your password by clicking 'Forgot Password' on the login page and following the instructions."},
    {"Question": "Do you have a mobile app?", "Answer": "Yes, we have a mobile app available on both iOS and Android platforms."},
    {"Question": "What is your privacy policy?", "Answer": "Our privacy policy outlines how we collect, use, and protect your data. You can view it on our website."},
    {"Question": "How do I report a defective product?", "Answer": "You can report a defective product by contacting our customer support team with your order details."},
    {"Question": "Do you offer product tutorials?", "Answer": "Yes, we offer product tutorials on our website and YouTube channel."},
    {"Question": "How can I leave a review for a product?", "Answer": "You can leave a review on the product page by clicking the 'Write a Review' button."},
    {"Question": "Do you have an affiliate program?", "Answer": "Yes, we have an affiliate program. You can sign up on our website to earn commissions on referrals."},
    {"Question": "What should I do if I receive the wrong product?", "Answer": "If you receive the wrong product, contact customer support to arrange a replacement or refund."},
    {"Question": "How do I delete my account?", "Answer": "You can delete your account by contacting our customer support team and requesting account deletion."},
    {"Question": "What are the benefits of subscribing to your newsletter?", "Answer": "Subscribing to our newsletter gives you access to exclusive deals, product updates, and industry news."},
    {"Question": "Do you offer eco-friendly packaging?", "Answer": "Yes, we offer eco-friendly packaging options for most of our products."},
    {"Question": "Can I place an order over the phone?", "Answer": "Yes, you can place an order over the phone by contacting our sales team."},
    {"Question": "What is your return address?", "Answer": "Our return address is provided in the 'Returns' section of our website and included in your order confirmation email."},
    {"Question": "How do I know if my payment went through?", "Answer": "You will receive a confirmation email once your payment has been processed successfully."},
    {"Question": "Can I gift a subscription?", "Answer": "Yes, you can gift a subscription. Select the 'Gift' option during the checkout process."},
    {"Question": "How do I access my digital downloads?", "Answer": "Digital downloads can be accessed through your account dashboard under 'My Downloads'."},
    {"Question": "What are your terms and conditions?", "Answer": "Our terms and conditions are available on our website and cover all aspects of using our services."},
    {"Question": "How do I find my order history?", "Answer": "You can find your order history in the 'My Account' section under 'Order History'."},
    {"Question": "Do you offer express shipping?", "Answer": "Yes, we offer express shipping for an additional fee. It can be selected during the checkout process."},
    {"Question": "Can I purchase a product as a gift?", "Answer": "Yes, you can purchase products as gifts and have them delivered directly to the recipient."},
    {"Question": "What is your policy on damaged items?", "Answer": "If you receive a damaged item, contact our support team within 7 days to arrange a replacement or refund."},
    {"Question": "Do you offer student discounts?", "Answer": "Yes, we offer student discounts. Verify your student status to receive a discount code."},
    {"Question": "Can I update my shipping address after placing an order?", "Answer": "Yes, you can update your shipping address within 24 hours of placing your order by contacting customer support."},
    {"Question": "How do I use store credit?", "Answer": "Store credit can be applied during checkout. Select 'Use Store Credit' in the payment options."},
    {"Question": "Are your products made in the USA?", "Answer": "Many of our products are made in the USA. Check the product page for specific manufacturing details."},
    {"Question": "Do you offer a trade-in program?", "Answer": "Yes, we offer a trade-in program for select products. Contact us for more details."},
    {"Question": "How do I cancel my order?", "Answer": "You can cancel your order within 24 hours of placement by contacting customer support."},
    {"Question": "What is the warranty period for refurbished products?", "Answer": "Refurbished products come with a 6-month warranty covering any defects."},
    {"Question": "Do you offer live chat support?", "Answer": "Yes, we offer live chat support on our website during business hours."},
    {"Question": "How can I verify my order status?", "Answer": "You can verify your order status by logging into your account and visiting the 'Order History' section."},
    {"Question": "What is the best way to contact customer service?", "Answer": "The best way to contact customer service is through our live chat or by emailing support@ourwebsite.com."},
    {"Question": "What is your customer service phone number?", "Answer": "You can reach our customer service at 1-800-123-4567."},
    {"Question": "Can I pay using multiple payment methods?", "Answer": "Currently, we only support a single payment method per transaction."},
    {"Question": "How do I subscribe to SMS alerts?", "Answer": "You can subscribe to SMS alerts by opting in on your account settings page."},
    {"Question": "Do you have a physical catalog?", "Answer": "We offer a digital catalog which can be downloaded from our website."},
    {"Question": "What is the average delivery time?", "Answer": "The average delivery time is 3-5 business days for standard shipping."},
    {"Question": "Can I save items for later?", "Answer": "Yes, you can add items to your wishlist and access them later."},
    {"Question": "What is the best way to clean product X?", "Answer": "The best way to clean product X is to use a soft cloth and mild soap."},
    {"Question": "Can I request a price match?", "Answer": "Yes, we offer a price match guarantee within 14 days of purchase."},
    {"Question": "Do you have a mobile app?", "Answer": "Yes, our mobile app is available on both iOS and Android."},
    {"Question": "Can I buy products in-store and online?", "Answer": "Yes, you can purchase products both in our physical stores and online."},
    {"Question": "Do you offer installation services?", "Answer": "Yes, we offer installation services for select products. Check the product details for more information."},
    {"Question": "How can I unsubscribe from emails?", "Answer": "You can unsubscribe from our emails by clicking the 'Unsubscribe' link at the bottom of any email."},
    {"Question": "Are there any hidden fees?", "Answer": "No, all fees are transparently displayed at checkout."},
    {"Question": "What are your accepted currencies?", "Answer": "We accept payments in USD, EUR, GBP, and several other major currencies."},
    {"Question": "Can I update my email address?", "Answer": "Yes, you can update your email address in the 'Account Settings' section."},
    {"Question": "Do you offer product samples?", "Answer": "Yes, product samples are available for select items."},
    {"Question": "Can I make a purchase without an account?", "Answer": "Yes, you can make a purchase as a guest, but creating an account offers additional benefits."},
    {"Question": "How do I find product dimensions?", "Answer": "Product dimensions are listed in the 'Specifications' section of the product page."},
    {"Question": "Can I gift wrap an item?", "Answer": "Yes, you can select gift wrapping during the checkout process for an additional fee."},
    {"Question": "What should I do if I forgot my password?", "Answer": "Click 'Forgot Password' on the login page to reset your password."},
    {"Question": "How do I contact technical support?", "Answer": "You can contact technical support via our help center or by calling our support hotline."},
    {"Question": "What is your most popular product?", "Answer": "Our most popular product is the UltraComfort Chair 2000."},
    {"Question": "Do you offer custom orders?", "Answer": "Yes, custom orders are available for select products. Contact us for more details."},
    {"Question": "Can I view my previous orders?", "Answer": "Yes, you can view your order history in the 'My Account' section."},
    {"Question": "Do you offer subscription boxes?", "Answer": "Yes, we offer subscription boxes for various product categories."},
    {"Question": "What is your cancellation policy?", "Answer": "You can cancel your order within 24 hours of placing it for a full refund."},
    {"Question": "Can I purchase items on backorder?", "Answer": "Yes, you can purchase backordered items and they will be shipped when available."},
    {"Question": "What are your business hours?", "Answer": "Our business hours are Monday to Friday, 9 AM to 5 PM."},
    {"Question": "Do you offer next-day delivery?", "Answer": "Yes, next-day delivery is available for an additional charge."},
    {"Question": "How do I find the nearest store?", "Answer": "Use our store locator on the website to find the nearest location."},
    {"Question": "Are your products recyclable?", "Answer": "Many of our products are recyclable. Check the product details for recycling information."},
    {"Question": "How can I find the latest deals?", "Answer": "The latest deals are featured on our homepage and in our newsletter."},
    {"Question": "Do you offer free returns?", "Answer": "Yes, we offer free returns within 30 days for most items."},
    {"Question": "How do I provide a review for a service?", "Answer": "Service reviews can be submitted through the feedback form on our website."},
    {"Question": "What is the expected shelf life of product Y?", "Answer": "The shelf life of product Y is approximately 12 months."},
    {"Question": "Can I get a replacement for a faulty item?", "Answer": "Yes, faulty items are eligible for a replacement under our warranty policy."},
    {"Question": "Do you offer student memberships?", "Answer": "Yes, student memberships are available with special discounts and perks."},
    {"Question": "How do I use a referral code?", "Answer": "Enter the referral code during checkout to receive your discount."},
    {"Question": "What safety measures do you have in place?", "Answer": "We adhere to strict safety standards and provide safety information with each product."},
    {"Question": "Can I set up a business account?", "Answer": "Yes, we offer business accounts with special pricing and bulk order options."},
    {"Question": "What happens if my order is delayed?", "Answer": "If your order is delayed, we will notify you via email with updated delivery information."},
    {"Question": "Do you offer virtual consultations?", "Answer": "Yes, virtual consultations are available for select products and services."},
    {"Question": "How do I report a website issue?", "Answer": "Report website issues through our 'Contact Us' page or by emailing support."},
    {"Question": "Can I schedule an in-store pickup?", "Answer": "Yes, in-store pickup is available for select items. Choose 'Pickup' at checkout."},
    {"Question": "Do you offer warranty extensions?", "Answer": "Yes, you can purchase warranty extensions during checkout or through your account."},
    {"Question": "How can I request a donation for my event?", "Answer": "Submit a donation request through our community support page."},
    {"Question": "What is your policy on out-of-stock items?", "Answer": "You can sign up for notifications to be alerted when out-of-stock items are available."},
    {"Question": "How do I leave feedback for an employee?", "Answer": "You can leave employee feedback through our 'Contact Us' page or customer support."},
    {"Question": "Do you have a customer loyalty card?", "Answer": "Yes, our loyalty card offers rewards points for every purchase."},
    {"Question": "Can I apply for a job through your website?", "Answer": "Yes, visit our 'Careers' page to view and apply for open positions."},
    {"Question": "How do I update my billing information?", "Answer": "Update your billing information in the 'Account Settings' section of our website."},
    {"Question": "Can I request a catalog by mail?", "Answer": "Yes, you can request a physical catalog by contacting our customer service."},
    {"Question": "Hello, how can I help you today?", "Answer": "Hi! I need some information about your products."},
    {"Question": "Good morning! What can I assist you with?", "Answer": "Good morning! I’m looking for details about your latest offers."},
    {"Question": "Hi there! Need help with anything?", "Answer": "Hi! Yes, I want to know about your return policy."},
    {"Question": "Welcome! How may I assist you?", "Answer": "Thank you! Can you tell me about your shipping options?"},
    {"Question": "Good afternoon! How can I be of service?", "Answer": "Good afternoon! I’d like to inquire about your bulk purchase discounts."},
    {"Question": "Hello! Do you have any questions for me?", "Answer": "Hello! Yes, I’m curious about your loyalty program."},
    {"Question": "Hi! What brings you here today?", "Answer": "Hi! I’m interested in learning about your warranty services."},
    {"Question": "Good evening! How can I help you?", "Answer": "Good evening! I need information on your customer support hours."},
    {"Question": "Greetings! What can I do for you?", "Answer": "Greetings! Can you provide me with details about your gift card options?"},
    {"Question": "Hello! How’s your day going?", "Answer": "Hello! It’s going well, thank you. I’d like to ask about your payment methods."},
    {"Question": "Welcome to our service! Need any help?", "Answer": "Thank you! I’m looking for guidance on how to track my order."},
    {"Question": "Good day! How can I assist?", "Answer": "Good day! I’d like some information on your product availability."},
    {"Question": "Hello! What information are you seeking today?", "Answer": "Hi! I need details about your subscription services."},
    {"Question": "Hi! What would you like to know?", "Answer": "Hi! I’m interested in your latest product launches."},
    {"Question": "Hello there! How can I support you today?", "Answer": "Hello! I’d like to know about your eco-friendly products."},
    {"Question": "Hey! Do you need assistance?", "Answer": "Hey! Yes, I’m wondering about your store locations."},
    {"Question": "Hi! How’s everything with you?", "Answer": "Hi! Everything’s great, thanks. Can you tell me about your special discounts?"},
    {"Question": "Welcome! Have any questions?", "Answer": "Yes, I’m interested in learning about your referral program."},
    {"Question": "Good morning! What can I do for you?", "Answer": "Good morning! I’d like to know about your delivery scheduling options."},
    {"Question": "Hello! Do you need help finding something?", "Answer": "Yes, I’d like to learn about your product customization services."},
    {"Question": "Good afternoon! How can I assist you today?", "Answer": "Good afternoon! I need information on how to leave a product review."},
    {"Question": "Hi there! What’s on your mind?", "Answer": "Hi! I’d like to ask about your next-day delivery service."},
    {"Question": "Hello! Need any help?", "Answer": "Hello! I’m looking for information about your product dimensions."},
    {"Question": "Good evening! How can I help you today?", "Answer": "Good evening! I’m interested in your gift wrapping services."},
    {"Question": "Greetings! What do you need assistance with?", "Answer": "Greetings! I’d like to know about your price matching policy."},
    {"Question": "Welcome! How can I make your day better?", "Answer": "Thanks! Can you tell me about your business account options?"},
    {"Question": "Hi! What brings you here?", "Answer": "Hi! I’m looking for details on your mobile app features."},
    {"Question": "Hello! How can I assist you today?", "Answer": "Hello! I’d like to inquire about your student membership benefits."},
    {"Question": "Good day! Do you have any questions for me?", "Answer": "Yes, I’m curious about your financing options."},
    {"Question": "Hey there! Need any help?", "Answer": "Hey! I want to know how to update my billing information."},
    {"Question": "Hi! How can I help you out today?", "Answer": "Hi! I’m looking for information on your return process."},
    {"Question": "Welcome! Do you have any queries?", "Answer": "Yes, I’m interested in your technical support services."},
    {"Question": "Good morning! What can I do for you?", "Answer": "Good morning! I need details about your upcoming product launches."},
    {"Question": "Hello! How may I be of service?", "Answer": "Hello! I’d like to know about your refund processing time."},
    {"Question": "Hi there! Can I assist you with anything?", "Answer": "Hi! I’m interested in learning about your seasonal sales."},
    {"Question": "Good evening! How can I help today?", "Answer": "Good evening! I’d like to know how to apply a discount code."},
    {"Question": "Greetings! Need any assistance?", "Answer": "Yes, I’m looking for information on your replacement part ordering process."},
    {"Question": "Hello! What can I do for you?", "Answer": "Hello! I need help with understanding your subscription boxes."},
    {"Question": "Hi! How’s your day going so far?", "Answer": "Hi! It’s going well, thanks. I’d like to ask about your product comparison feature."},
    {"Question": "Welcome! Any questions I can answer?", "Answer": "Yes, I’m interested in your eco-friendly packaging."},
    {"Question": "Good day! How can I support you?", "Answer": "Good day! I need information about your preorder options."},
    {"Question": "Hey! What would you like to know?", "Answer": "Hey! I want to know about your shipping rates for international orders."},
    {"Question": "Hello there! Do you have any queries?", "Answer": "Yes, I’d like to ask about your loyalty card program."},
    {"Question": "Hi! How can I make your shopping experience better?", "Answer": "Hi! I’d like to know about your customer feedback process."},
    {"Question": "Welcome! What can I help you with today?", "Answer": "Thank you! I need details about your out-of-stock item notifications."},
    {"Question": "Good morning! How can I assist you today?", "Answer": "Good morning! I’d like to learn about your customer service contact options."},
    {"Question": "Hello! Need help with anything specific?", "Answer": "Yes, I’m curious about your environmental policy."},
    {"Question": "Hi! What brings you here today?", "Answer": "Hi! I’m looking for information on your bulk order discounts."},
    {"Question": "Hello! How can I assist you?", "Answer": "Hello! I want to know about your product warranty extensions."},
    {"Question": "Good evening! What can I do for you?", "Answer": "Good evening! I’d like to ask about your free sample policy."},
    {"Question": "Greetings! Do you have any questions for me?", "Answer": "Yes, I’m interested in learning about your free returns policy."},
    {"Question": "Welcome! How can I help you today?", "Answer": "Thanks! I’d like to know how to leave feedback for an employee."},
    {"Question": "Hi! Is there anything I can assist you with?", "Answer": "Hi! I’m looking for details on your in-store pickup options."},
    {"Question": "Good day! Need any help?", "Answer": "Yes, I want to know about your latest deals and offers."},
    {"Question": "Hello! How can I make your visit better?", "Answer": "Hello! I need information on how to subscribe to your newsletter."},
    {"Question": "Hi there! How can I assist you today?", "Answer": "Hi! I’m curious about your customer loyalty programs."},
    {"Question": "Welcome! What can I help you find?", "Answer": "I’m looking for details about your financing options for large purchases."},
    {"Question": "Good morning! Any questions for me?", "Answer": "Good morning! I’d like to ask about your technical support services."},

]

# Save to CSV file within Colab environment
file_path = 'sales_qa_pairs.csv'  # Use a simple filename
with open(file_path, 'w', newline='', encoding='utf-8') as file: # Added encoding for potential special characters
    writer = csv.DictWriter(file, fieldnames=["Question", "Answer"])
    writer.writeheader()
    writer.writerows(qa_pairs)

print("CSV file created successfully.")

# Download the CSV file to your local machine
files.download(file_path)
# Out:
# CSV file created successfully.

# %%
import pandas as pd

# Define the file path
file_path = r'C:\Users\jhasn\OneDrive\Desktop\AI AND ML TRAINING PROJECTS\Encode\sales_qa_pairs.csv'  # Use raw string (r'') for Windows paths

# Load the data
df = pd.read_csv(file_path, encoding='utf-8') # Specify encoding

# Clean the 'Question' and 'Answer' columns
df['Question'] = df['Question'].str.replace('â€™', "'", regex=True)
df['Answer'] = df['Answer'].str.replace('â€™', "'", regex=True)

# Save the cleaned data
df.to_csv(file_path.replace('.csv', '_cleaned.csv'), index=False, encoding='utf-8') # Specify encoding
